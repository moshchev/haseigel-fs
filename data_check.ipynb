# %%
import pandas as pd
from pprint import pp
from IPython.display import display, HTML

# %%
data = pd.read_json('data/test_10.json')
data
# Out:
#    reference_id  domain_start_id  \
# 0         23884             3292
# 1         65092             1265
# 2        193015              278
# 3         84150             1187
# 4         72410             3308
# 5        193634              181
# 6         43718             1189
# 7         98087             1867
# 8        193619              278
# 9         98901             2378
#
#                                         response_url  \
# 0  https://bianchi-industrial.it/products/linear-...
# 1  https://vilagrancha.com/en/1292-complete-clutc...
# 2  https://www.groupe-lechevalier.com/produit/rou...
# 3  https://dachnikof.ru/products/Hozblok_Greensto...
# 4  https://www.bell.si/Lepila-in-tesnilne-mase/cy...
# 5         https://podshipnik-mo.ru/stopornyye-shayby
# 6    https://www.kalydon.com.ar/ubicacion-unica/gba/
# 7  https://www.nicotechnika.hu/hu/szigetelt-szers...
# 8  https://www.groupe-lechevalier.com/produit/tra...
# 9  https://www.lemu.dk/da/catalog/roer-og-fitting...
#
# ...

# %%
display(HTML(data['response_text'][0]))
# Out:
# <!doctypehtml><html class=no-js lang=en-GB><meta charset=utf-8><meta content=IE=edge http-equiv=X-UA-Compatible><meta content=width=device-width,initial-scale=1 name=viewport><meta content=#009fe3 name=theme-color><link href=https://bianchi-industrial.it/xmlrpc.php rel=pingback><meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1"name=robots><title>Oscillating Actuators, Grippers, Handling Solutions- Bianchi Industrial</title><meta content="Bianchi Industrial offers different technical solutions all the product lines designed by Festo to implement all types of handling."name=description><link href=https://bianchi-industrial.it/products/linear-motion-and-automation/automation/oscillating-actuators-grippers-handling-solutions/ rel=canonical><meta content=en_GB property=og:locale><meta content=it_IT property=og:locale:alternate><meta content=article property=og:type><meta content="Oscillating Actuators, Grippers, Handling Solutions- Bianchi Industr
# ...

# %%
data['response_text'][0]
# Out:
# '<!doctypehtml><html class=no-js lang=en-GB><meta charset=utf-8><meta content=IE=edge http-equiv=X-UA-Compatible><meta content=width=device-width,initial-scale=1 name=viewport><meta content=#009fe3 name=theme-color><link href=https://bianchi-industrial.it/xmlrpc.php rel=pingback><meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1"name=robots><title>Oscillating Actuators, Grippers, Handling Solutions- Bianchi Industrial</title><meta content="Bianchi Industrial offers different technical solutions all the product lines designed by Festo to implement all types of handling."name=description><link href=https://bianchi-industrial.it/products/linear-motion-and-automation/automation/oscillating-actuators-grippers-handling-solutions/ rel=canonical><meta content=en_GB property=og:locale><meta content=it_IT property=og:locale:alternate><meta content=article property=og:type><meta content="Oscillating Actuators, Grippers, Handling Solutions- Bianchi Indust
# ...
