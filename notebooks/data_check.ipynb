# %%
import pandas as pd
from pprint import pp
from IPython.display import display, HTML

# %%
data10 = pd.read_json('data/test_10.json')
data10
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data10 = pd.read_json('data/test_10.json')
#       2 data10
#
# File ~/miniconda3/envs/haseUNDigel/lib/python3.10/site-packages/pandas/io/json/_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
#     798     keep_default_dates=keep_default_dates,
#     799     precise_float=precise_float,
#     800     date_unit=date_unit,
#     801     encoding=encoding,
#     802     lines=lines,
#     803     chunksize=chunksize,
#     804     compression=compression,
#     805     nrows=nrows,
#     806     storage_options=storage_options,
#     807     encoding_errors=encoding_errors,
#     808     dtype_backend=dtype_backend,
#     809     engine=engine,
#     810 )
#     812 if chunksize:
#     813     return json_reader
#
# File ~/miniconda3/envs/haseUNDigel/lib/python3.10/site-packages/pandas/io/json/_json.py:904, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     902     self.data = filepath_or_buffer
#     903 elif self.engine == "ujson":
# --> 904     data = self._get_data_from_filepath(filepath_or_buffer)
#     905     self.data = self._preprocess_data(data)
#
# File ~/miniconda3/envs/haseUNDigel/lib/python3.10/site-packages/pandas/io/json/_json.py:960, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     952     filepath_or_buffer = self.handles.handle
#     953 elif (
#     954     isinstance(filepath_or_buffer, str)
#     955     and filepath_or_buffer.lower().endswith(
#    (...)
#     958     and not file_exists(filepath_or_buffer)
#     959 ):
# --> 960     raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     961 else:
#     962     warnings.warn(
#     963         "Passing literal json to 'read_json' is deprecated and "
#     964         "will be removed in a future version. To read from a "
#    (...)
#     967         stacklevel=find_stack_level(),
#     968     )
#
# FileNotFoundError: File data/test_10.json does not exist

# %%
data500 = pd.read_json('data/test_500.json')
data500.head(10)
# Out:
#    reference_id  domain_start_id  \
# 0         81186             1857
# 1         28399             2312
# 2         52992             1193
# 3         19021             1357
# 4        174252               45
# 5         40556              219
# 6         33594              811
# 7        101817             2763
# 8        108667              613
# 9         61820             1261
#
#                                         response_url  \
# 0                   https://www.parduyns.be/services
# 1  https://www.mcmaster.com/products/belt-tension...
# 2  https://emmecci.it/categoria-prodotto/bricolag...
# 3  https://www.endas.com/404?aspxerrorpath=/newsl...
# 4  https://www.tinphatco.vn/ct/3m-thuoc-cuon-thep...
# 5           https://www.beltmarket.ru/catalog/tsepi/
# 6  https://www.industrial.cz/kategorie/retezy-a-r...
# 7           https://intranet.enriel.com/en/dashboard
# 8  https://kamatics.com/innovations/custom-engine...
# 9  https://pigu.lt/lt/buitine-technika-ir-elektro...
#
#                                        response_text
# 0  <!doctypehtml><html lang=fr><meta charset=utf-...
# 1  <!doctypehtml><html lang=en xmlns=http://www.w...
# 2  <!doctypehtml><html class="html_stretched resp...
# 3  <!doctypehtml PUBLIC "-//W3C//DTD XHTML 1.0 Tr...
# 4  <!doctypehtml><meta content="text/html; charse...
# 5  <!doctypehtml><html lang=ru xmlns=http://www.w...
# 6  <!doctypehtml><html id=ctl00_html1 lang=cs xml...
# 7  <!doctypehtml><meta charset=utf-8><meta conten...
# 8  <!doctypehtml><html lang=en><meta charset=utf-...
# 9  <!doctypehtml><html class="no-animations theme...

# %%
data = pd.concat((data10, data500))
data.reset_index(drop=True, inplace=True)

# %%
from dotenv import load_dotenv
assert load_dotenv()

# %%
# bring data to db
import os
from sqlalchemy import create_engine

host = os.getenv('DB_HOST')
database = os.getenv('DB_NAME')
user = os.getenv('DB_USER')
password = os.getenv('DB_PASS')
port = os.getenv('DB_PORT')

connection_string  = f'postgresql://{user}:{password}@{host}:{port}/{database}'
engine =  create_engine(connection_string)

data.to_sql('html_data', engine, 'public', if_exists='append', index=False)
# Out:
# Connected to PostgreSQL version: ('PostgreSQL 16.4 on aarch64-unknown-linux-gnu, compiled by gcc (GCC) 7.3.1 20180712 (Red Hat 7.3.1-17), 64-bit',)

# %%
# get the data
df = pd.read_sql('select * from html_data limit 10', engine)
df.head()
# Out:
#    reference_id  domain_start_id  \
# 0         23884             3292
# 1         65092             1265
# 2        193015              278
# 3         84150             1187
# 4         72410             3308
#
#                                         response_url  \
# 0  https://bianchi-industrial.it/products/linear-...
# 1  https://vilagrancha.com/en/1292-complete-clutc...
# 2  https://www.groupe-lechevalier.com/produit/rou...
# 3  https://dachnikof.ru/products/Hozblok_Greensto...
# 4  https://www.bell.si/Lepila-in-tesnilne-mase/cy...
#
#                                        response_text
# 0  <!doctypehtml><html class=no-js lang=en-GB><me...
# 1  <!doctypehtml><html lang=en><meta charset=utf-...
# 2  <!doctypehtml><html lang=fr xml:lang=fr xmlns:...
# 3  <!doctypehtml><html lang=ru-RU><meta content="...
# 4  <!doctypehtml><html lang=sl><meta charset=utf-...
